# %%
import matplotlib.pyplot as plt
import pickle
import numpy as np

# %%
roll = 100

# %%
reward = pickle.load(open("./train_logs/vpg_rewards.pkl", "rb"))

# %%
reward = np.array(reward)

# %%
plt.plot(np.convolve(reward, np.ones(roll), 'valid')/roll)
